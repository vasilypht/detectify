# %%
import json
from abc import ABC
from pathlib import Path

import pandas as pd
import torch
from torch import nn
from torch.utils.data import (
    DataLoader,
    Dataset,
)
from transformers import (
    BertTokenizer,
)

# %%
NOTEBOOKS_DIR = Path().resolve()
PROJECT_DIR = NOTEBOOKS_DIR.parent
DATA_DIR = PROJECT_DIR / 'data'

REPORTS_DIR = DATA_DIR / 'reports'
MALWARE_REPORTS_DIR = REPORTS_DIR / 'malware'
BENIGN_REPORTS_DIR = REPORTS_DIR / 'benign'

EXE_DIR = DATA_DIR / 'exe'
MALWARE_EXE_DIR = EXE_DIR / 'malware'
BENIGN_EXE_DIR = EXE_DIR / 'malware'

RANDOM_STATE = 741

TOKENIZER_OPTIONS = {
    'add_special_tokens': True,
    'max_length': 224,
    'padding': 'max_length',
    'return_token_type_ids': False,
    'return_attention_mask': False,
    'truncation': True,
    'return_tensors': 'pt',
}

# %%
df_train = pd.read_parquet(DATA_DIR / 'df_train.parquet')
df_valid = pd.read_parquet(DATA_DIR / 'df_valid.parquet')
df_test = pd.read_parquet(DATA_DIR / 'df_test.parquet')

# %%
class MalwareDetectionDataset(Dataset, ABC):
    def __init__(
            self,
            df: pd.DataFrame,
            bert_tokenizer: str = 'bert-base-uncased',
    ):
        super(MalwareDetectionDataset, self).__init__()
        self._df = df
        self._tokenizer = BertTokenizer.from_pretrained(bert_tokenizer)

    def __len__(self):
        return self._df.shape[0]

    def __getitem__(self, item):
        row = self._df.iloc[item]

        if row.LABEL == 'malware':
            file_path = MALWARE_EXE_DIR / f'{row.HASH}.exe'
        elif row.LABEL == 'benign':
            file_path = BENIGN_EXE_DIR / f'{row.HASH}.exe'
        else:
            raise NotImplementedError()

        with file_path.open('rb') as _file:
            data = _file.read(224 * 224)

        padding = [0] * (224*224 - len(data))
        data.extend(padding)

        img = torch.reshape(
            input=torch.tensor(data, dtype=torch.short),
            shape=(224, 224),
        )

        # to rgb
        img = torch.stack([img, img, img])

        return {
            'static': img,
            'label_id': torch.tensor(row.LABEL_ID, dtype=torch.long),
        }

# %%
print(df_train.iloc[1].HASH)
print(df_train.iloc[1].LABEL)
# Out:
# 0624469d0b2ecdef04549cea8cfe1300009c0b2fbdce70b78aa7f66d00220d0b
# malware

# %%
with open(MALWARE_REPORTS_DIR / 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'files': {'data': {'attributes': {'type_description': 'Win32 EXE',
#     'tlsh': 'T1C4840152FC534D7AD199B6F5098A5622173DCD8A1B0D40071AFC38A4B9732BBCD8B1EE',
#     'vhash': '035046751d757025z30048nz5fz',
#     'type_tags': ['executable', 'windows', 'win32', 'pe', 'peexe'],
#     'creation_date': 1332087689,
#     'names': ['cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7.exe',
#      'c977ca5f506ae887d16aca79845b0838010f6ec3.exe'],
#     'last_modification_date': 1679309327,
#     'type_tag': 'peexe',
#     'times_submitted': 3,
#     'total_votes': {'harmless': 0, 'malicious': 0},
#     'size': 393216,
#     'popular_threat_classification': {'suggested_threat_label': 'trojan.emotetu/byynvrfi',
#      'popular_threat_category': [{'count': 24, 'value': 'trojan'},
#       {'count': 10, 'value': 'fakeav'}],
#      'popular_threat_name': [{'count': 7, 'value': 'emotetu'},
#       {'count': 6, 'value': 'byynvrfi'},
#       {'count': 2, 'value': 'obfuscator'}]},
#     'authentihash': '5b63cc470dca2fa8d07eda731c65b57c4d2d444af2470808a48a1843440e50db',
#     'detectiteasy': {'filetype': 'PE32',
#      'values': [{'info': 'EXE32',
#        'version': '2003 v.7.1 (3052-9782)',
#        'type': 'Compiler',
#        'name': 'EP:Microsoft Visual C/C++'},
#       {'info': 'libcmt',
#        'version': '2002',
#        'type': 'Compiler',
#        'name': 'Microsoft Visual C/C++'},
#       {'info': 'GUI32',
#        'version': '7.0',
#        'type': 'Linker',
#        'name': 'Microsoft Linker'}]},
#     'last_submission_date': 1679302025,
#     'meaningful_name': 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7.exe',
#     'trid': [{'file_type': 'Win32 Executable MS Visual C++ (generic)',
#       'probability': 47.3},
#      {'file_type': 'Win64 Executable (generic)', 'probability': 15.9},
#      {'file_type': 'Win32 Dynamic Link Library (generic)', 'probability': 9.9},
#      {'file_type': 'Win16 NE executable (generic)', 'probability': 7.6},
#      {'file_type': 'Win32 Executable (generic)', 'probability': 6.8}],
#     'sha256': 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7',
#     'type_extension': 'exe',
#     'tags': ['peexe', 'spreader'],
#     'last_analysis_date': 1679302025,
#     'unique_sources': 3,
#     'first_submission_date': 1383156037,
#     'sha1': 'c977ca5f506ae887d16aca79845b0838010f6ec3',
#     'ssdeep': '6144:I4UxdtEeFGG4ipAes8QOrL8eu2S0Ez9/2LOrkuXVplH0v0r+QiRlb:I4UxTEHGna822SlrkuyHb',
#     'packers': {'PEiD': 'Microsoft Visual C++ v7.0'},
#     'md5': 'ab2f51333e09dbec4b7f618c9d8662cd',
#     'pe_info': {'resource_details': [{'lang': 'ENGLISH US',
#        'entropy': 5.190262794494629,
#        'chi2': 342165.22,
#        'filetype': 'unknown',
#        'sha256': 'b5e3e73b30056509ace70828445fbe55011bf12db200342dfef22a0a9c6179ff',
#        'type': 'RT_ICON'},
#       {'lang': 'ENGLISH US',
#        'entropy': 4.927060127258301,
#        'chi2': 162691.11,
#        'filetype': 'unknown',
#        'sha256': '5774be0992c3057b4ab3d5552e339e7478e003a8d06666650c9a769d221597d4',
#        'type': 'RT_ICON'},
#       {'lang': 'ENGLISH US',
#        'entropy': 7.9636335372924805,
#        'chi2': 255.81,
#        'filetype': 'unknown',
#        'sha256': 'feef39d4bbbabb27a6c0ee12070e48ce4bc61af30e8d99b2e55c49d43bbada5d',
#        'type': 'RT_RCDATA'},
#       {'lang': 'ENGLISH US',
#        'entropy': 7.568905830383301,
#        'chi2': 27901.0,
#        'filetype': 'unknown',
#        'sha256': 'b410a3ff04ddd65e023e20680ef78dbb3f8f34eae9560f5b09d6440ffbd6b9ec',
#        'type': 'RT_RCDATA'},
#       {'lang': 'ENGLISH US',
#        'entropy': 2.2327966690063477,
#        'chi2': 2751.88,
#        'filetype': 'ICO',
#        'sha256': '45a49bbb1c7c31038f9134c98604739dade19b7128608fbf3cc511ea116a7469',
#        'type': 'RT_GROUP_ICON'}],
#      'rich_pe_header_hash': 'c3a53bafa0d6053935cb210f19c8aedf',
#      'imphash': 'a82a23e8fcbf8f0178b1396b23fd468d',
#      'compiler_product_versions': ['[ASM] VS2002 (.NET) build 9466 count=20',
#       '[ C ] VS2002 (.NET) build 9466 count=66',
#       'id: 25, version: 9210 count=11',
#       '[---] Unmarked objects count=97',
#       '[C++] VS2002 (.NET) build 9466 count=3',
#       '[RES] VS2002 (.NET) build 9466 count=1',
#       '[LNK] VS2002 (.NET) build 9466 count=1'],
#      'resource_langs': {'ENGLISH US': 5},
#      'machine_type': 332,
#      'timestamp': 1332087689,
#      'resource_types': {'RT_ICON': 2, 'RT_GROUP_ICON': 1, 'RT_RCDATA': 2},
#      'sections': [{'name': '.text',
#        'chi2': 30202.92,
#        'virtual_address': 4096,
#        'flags': 'rx',
#        'raw_size': 98304,
#        'entropy': 7.89,
#        'virtual_size': 97556,
#        'md5': 'f1be5ee8c08b75856eadf18066e24b17'},
#       {'name': '.rdata',
#        'chi2': 388825.38,
#        'virtual_address': 102400,
#        'flags': 'r',
#        'raw_size': 8192,
#        'entropy': 4.32,
#        'virtual_size': 6168,
#        'md5': 'e21953e17407130b766a9100a5f7cb3e'},
#       {'name': '.data',
#        'chi2': 1858585.62,
#        'virtual_address': 110592,
#        'flags': 'rw',
#        'raw_size': 233472,
#        'entropy': 7.23,
#        'virtual_size': 646520,
#        'md5': 'd54d7dbfaae708334e6e7f749b5266ce'},
#       {'name': '.rsrc',
#        'chi2': 198719.53,
#        'virtual_address': 757760,
#        'flags': 'r',
#        'raw_size': 49152,
#        'entropy': 7.19,
#        'virtual_size': 47200,
#        'md5': 'ac8defe145f23466183e018f3956ae2a'}],
#      'import_list': [{'library_name': 'ADVAPI32.dll',
#        'imported_functions': ['ConvertSidToStringSidW',
#         'ConvertStringSidToSidW']},
#       {'library_name': 'KERNEL32.dll',
#        'imported_functions': ['CloseHandle',
#         'CreateFileA',
#         'DeleteCriticalSection',
#         'EnterCriticalSection',
#         'ExitProcess',
#         'FindClose',
#         'FreeEnvironmentStringsA',
#         'FreeEnvironmentStringsW',
#         'GetACP',
#         'GetCommandLineA',
#         'GetCPInfo',
#         'GetCurrentProcess',
#         'GetCurrentProcessId',
#         'GetCurrentThread',
#         'GetCurrentThreadId',
#         'GetEnvironmentStrings',
#         'GetEnvironmentStringsW',
#         'GetFileType',
#         'GetLastError',
#         'GetLocaleInfoA',
#         'GetModuleFileNameA',
#         'GetModuleHandleA',
#         'GetOEMCP',
#         'GetProcAddress',
#         'GetStartupInfoA',
#         'GetStdHandle',
#         'GetStringTypeA',
#         'GetStringTypeW',
#         'GetSystemInfo',
#         'GetSystemTime',
#         'GetSystemTimeAsFileTime',
#         'GetTickCount',
#         'GetVersionExA',
#         'GlobalLock',
#         'HeapAlloc',
#         'HeapCreate',
#         'HeapDestroy',
#         'HeapFree',
#         'HeapLock',
#         'HeapReAlloc',
#         'HeapSize',
#         'InitializeCriticalSection',
#         'LCMapStringA',
#         'LCMapStringW',
#         'LeaveCriticalSection',
#         'LoadLibraryA',
#         'LocalSize',
#         'LockFile',
#         'lstrcatA',
#         'MultiByteToWideChar',
#         'OpenMutexA',
#         'PulseEvent',
#         'QueryPerformanceCounter',
#         'ReadFile',
#         'RtlUnwind',
#         'SetFilePointer',
#         'SetHandleCount',
#         'SetLastError',
#         'TerminateProcess',
#         'TlsAlloc',
#         'TlsFree',
#         'TlsGetValue',
#         'TlsSetValue',
#         'UnhandledExceptionFilter',
#         'UnlockFile',
#         'VirtualAlloc',
#         'VirtualFree',
#         'VirtualProtect',
#         'VirtualProtectEx',
#         'VirtualQuery',
#         'WideCharToMultiByte',
#         'WriteFile']},
#       {'library_name': 'USER32.dll',
#        'imported_functions': ['BeginPaint',
#         'DestroyWindow',
#         'GetSysColorBrush',
#         'GetWindow',
#         'wsprintfA']},
#       {'library_name': 'GDI32.dll',
#        'imported_functions': ['CreateBrushIndirect',
#         'CreateDIBPatternBrush',
#         'SelectObject']},
#       {'library_name': 'MSVFW32.dll',
#        'imported_functions': ['DrawDibTime', 'ICOpen']}],
#      'entry_point': 83269},
#     'magic': 'PE32 executable for MS Windows (GUI) Intel 80386 32-bit',
#     'last_analysis_stats': {'harmless': 0,
#      'type-unsupported': 4,
#      'suspicious': 0,
#      'confirmed-timeout': 0,
#      'timeout': 1,
#      'failure': 0,
#      'malicious': 56,
#      'undetected': 12},
#     'last_analysis_results': {'Bkav': {'category': 'malicious',
#       'engine_name': 'Bkav',
#       'engine_version': '1.3.0.9899',
#       'result': 'W32.AIDetectNet.01',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Lionic': {'category': 'malicious',
#       'engine_name': 'Lionic',
#       'engine_version': '7.5',
#       'result': 'Trojan.Win32.Agent.lvqf',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Elastic': {'category': 'malicious',
#       'engine_name': 'Elastic',
#       'engine_version': '4.0.80',
#       'result': 'malicious (high confidence)',
#       'method': 'blacklist',
#       'engine_update': '20230302'},
#      'DrWeb': {'category': 'malicious',
#       'engine_name': 'DrWeb',
#       'engine_version': '7.0.59.12300',
#       'result': 'Trojan.AVKill.15496',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Cynet': {'category': 'malicious',
#       'engine_name': 'Cynet',
#       'engine_version': '4.0.0.27',
#       'result': 'Malicious (score: 100)',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'CMC': {'category': 'undetected',
#       'engine_name': 'CMC',
#       'engine_version': '2.4.2022.1',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230312'},
#      'CAT-QuickHeal': {'category': 'malicious',
#       'engine_name': 'CAT-QuickHeal',
#       'engine_version': '22.00',
#       'result': 'FraudTool.Security',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'McAfee': {'category': 'malicious',
#       'engine_name': 'McAfee',
#       'engine_version': '6.0.6.653',
#       'result': 'FakeAV-SecurityTool.km',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Malwarebytes': {'category': 'malicious',
#       'engine_name': 'Malwarebytes',
#       'engine_version': '4.5.5.54',
#       'result': 'Malware.AI.964094800',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Zillya': {'category': 'malicious',
#       'engine_name': 'Zillya',
#       'engine_version': '2.0.0.4834',
#       'result': 'Trojan.Agent.Win32.435033',
#       'method': 'blacklist',
#       'engine_update': '20230317'},
#      'Sangfor': {'category': 'malicious',
#       'engine_name': 'Sangfor',
#       'engine_version': '2.23.0.0',
#       'result': 'Suspicious.Win32.Save.ins',
#       'method': 'blacklist',
#       'engine_update': '20230317'},
#      'K7AntiVirus': {'category': 'malicious',
#       'engine_name': 'K7AntiVirus',
#       'engine_version': '12.72.47344',
#       'result': 'Trojan ( 00390f6f1 )',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Alibaba': {'category': 'malicious',
#       'engine_name': 'Alibaba',
#       'engine_version': '0.3.0.5',
#       'result': 'VirTool:Win32/Obfuscator.9ce8c283',
#       'method': 'blacklist',
#       'engine_update': '20190527'},
#      'K7GW': {'category': 'malicious',
#       'engine_name': 'K7GW',
#       'engine_version': '12.72.47346',
#       'result': 'Trojan ( 00390f6f1 )',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'CrowdStrike': {'category': 'malicious',
#       'engine_name': 'CrowdStrike',
#       'engine_version': '1.0',
#       'result': 'win/malicious_confidence_100% (D)',
#       'method': 'blacklist',
#       'engine_update': '20220812'},
#      'BitDefenderTheta': {'category': 'malicious',
#       'engine_name': 'BitDefenderTheta',
#       'engine_version': '7.2.37796.0',
#       'result': 'Gen:NN.ZexaF.36344.yqW@ayYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230313'},
#      'VirIT': {'category': 'undetected',
#       'engine_name': 'VirIT',
#       'engine_version': '9.5.410',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230317'},
#      'Cyren': {'category': 'malicious',
#       'engine_name': 'Cyren',
#       'engine_version': '6.5.1.2',
#       'result': 'W32/FakeAlert.TN.gen!Eldorado',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'SymantecMobileInsight': {'category': 'type-unsupported',
#       'engine_name': 'SymantecMobileInsight',
#       'engine_version': '2.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230119'},
#      'Symantec': {'category': 'timeout',
#       'engine_name': 'Symantec',
#       'engine_version': '1.19.0.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'tehtris': {'category': 'undetected',
#       'engine_name': 'tehtris',
#       'engine_version': 'v0.1.4',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'ESET-NOD32': {'category': 'malicious',
#       'engine_name': 'ESET-NOD32',
#       'engine_version': '26930',
#       'result': 'Win32/Adware.SystemSecurity.AK',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'APEX': {'category': 'malicious',
#       'engine_name': 'APEX',
#       'engine_version': '6.398',
#       'result': 'Malicious',
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'Paloalto': {'category': 'malicious',
#       'engine_name': 'Paloalto',
#       'engine_version': '0.9.0.1003',
#       'result': 'generic.ml',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'ClamAV': {'category': 'undetected',
#       'engine_name': 'ClamAV',
#       'engine_version': '1.0.1.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Kaspersky': {'category': 'malicious',
#       'engine_name': 'Kaspersky',
#       'engine_version': '22.0.1.28',
#       'result': 'Trojan-FakeAV.Win32.Agent.dlh',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'BitDefender': {'category': 'malicious',
#       'engine_name': 'BitDefender',
#       'engine_version': '7.2',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'NANO-Antivirus': {'category': 'malicious',
#       'engine_name': 'NANO-Antivirus',
#       'engine_version': '1.0.146.25743',
#       'result': 'Trojan.Win32.Fakeav.llkxt',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'SUPERAntiSpyware': {'category': 'malicious',
#       'engine_name': 'SUPERAntiSpyware',
#       'engine_version': '5.6.0.1032',
#       'result': 'Trojan.Agent/Gen-FraudAntiSpy',
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'MicroWorld-eScan': {'category': 'malicious',
#       'engine_name': 'MicroWorld-eScan',
#       'engine_version': '14.0.409.0',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Avast': {'category': 'malicious',
#       'engine_name': 'Avast',
#       'engine_version': '22.11.7701.0',
#       'result': 'Win32:FakeAlert-CGP [Trj]',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Tencent': {'category': 'malicious',
#       'engine_name': 'Tencent',
#       'engine_version': '1.0.0.1',
#       'result': 'Malware.Win32.Gencirc.1189d2ae',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Trustlook': {'category': 'type-unsupported',
#       'engine_name': 'Trustlook',
#       'engine_version': '1.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Sophos': {'category': 'malicious',
#       'engine_name': 'Sophos',
#       'engine_version': '2.1.2.0',
#       'result': 'Mal/FakeAV-CZ',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'F-Secure': {'category': 'undetected',
#       'engine_name': 'F-Secure',
#       'engine_version': '18.10.1137.128',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Baidu': {'category': 'undetected',
#       'engine_name': 'Baidu',
#       'engine_version': '1.0.0.2',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20190318'},
#      'VIPRE': {'category': 'malicious',
#       'engine_name': 'VIPRE',
#       'engine_version': '6.0.0.35',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'TrendMicro': {'category': 'malicious',
#       'engine_name': 'TrendMicro',
#       'engine_version': '11.0.0.1006',
#       'result': 'TROJ_FAKEAV.SMU4',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'McAfee-GW-Edition': {'category': 'malicious',
#       'engine_name': 'McAfee-GW-Edition',
#       'engine_version': 'v2021.2.0+4045',
#       'result': 'BehavesLike.Win32.FakeAVSecurityTool.fc',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Trapmine': {'category': 'malicious',
#       'engine_name': 'Trapmine',
#       'engine_version': '4.0.10.141',
#       'result': 'malicious.high.ml.score',
#       'method': 'blacklist',
#       'engine_update': '20230103'},
#      'FireEye': {'category': 'malicious',
#       'engine_name': 'FireEye',
#       'engine_version': '35.24.1.0',
#       'result': 'Generic.mg.ab2f51333e09dbec',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Emsisoft': {'category': 'malicious',
#       'engine_name': 'Emsisoft',
#       'engine_version': '2022.6.0.32461',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi (B)',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Ikarus': {'category': 'malicious',
#       'engine_name': 'Ikarus',
#       'engine_version': '6.0.33.0',
#       'result': 'Trojan.Win32.FakeAV',
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'GData': {'category': 'malicious',
#       'engine_name': 'GData',
#       'engine_version': 'A:25.35487B:27.31029',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Jiangmin': {'category': 'malicious',
#       'engine_name': 'Jiangmin',
#       'engine_version': '16.0.100',
#       'result': 'Trojan.Agent.tf',
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'Webroot': {'category': 'malicious',
#       'engine_name': 'Webroot',
#       'engine_version': '1.0.0.403',
#       'result': 'W32.Rogue.Gen',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Avira': {'category': 'malicious',
#       'engine_name': 'Avira',
#       'engine_version': '8.3.3.16',
#       'result': 'TR/Winwebsec.A.1800',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'MAX': {'category': 'malicious',
#       'engine_name': 'MAX',
#       'engine_version': '2023.1.4.1',
#       'result': 'malware (ai score=80)',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Antiy-AVL': {'category': 'malicious',
#       'engine_name': 'Antiy-AVL',
#       'engine_version': '3.0',
#       'result': 'Trojan[FakeAV]/Win32.Agent',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Gridinsoft': {'category': 'undetected',
#       'engine_name': 'Gridinsoft',
#       'engine_version': '1.0.110.174',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Xcitium': {'category': 'malicious',
#       'engine_name': 'Xcitium',
#       'engine_version': '35509',
#       'result': 'TrojWare.Win32.FakeAV.CVM@4n2sr4',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Arcabit': {'category': 'malicious',
#       'engine_name': 'Arcabit',
#       'engine_version': '2022.0.0.18',
#       'result': 'Trojan.EmotetU.Gen.E7CAAC',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'ViRobot': {'category': 'undetected',
#       'engine_name': 'ViRobot',
#       'engine_version': '2014.3.20.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'ZoneAlarm': {'category': 'malicious',
#       'engine_name': 'ZoneAlarm',
#       'engine_version': '1.0',
#       'result': 'HEUR:Trojan.Win32.Generic',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Avast-Mobile': {'category': 'type-unsupported',
#       'engine_name': 'Avast-Mobile',
#       'engine_version': '230319-00',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'Microsoft': {'category': 'malicious',
#       'engine_name': 'Microsoft',
#       'engine_version': '1.1.20100.6',
#       'result': 'VirTool:Win32/Obfuscator.AFQ',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Google': {'category': 'malicious',
#       'engine_name': 'Google',
#       'engine_version': '1679299239',
#       'result': 'Detected',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'BitDefenderFalx': {'category': 'type-unsupported',
#       'engine_name': 'BitDefenderFalx',
#       'engine_version': '2.0.936',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230203'},
#      'AhnLab-V3': {'category': 'malicious',
#       'engine_name': 'AhnLab-V3',
#       'engine_version': '3.23.1.10344',
#       'result': 'Trojan/Win32.FakeAV.R22664',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Acronis': {'category': 'undetected',
#       'engine_name': 'Acronis',
#       'engine_version': '1.2.0.114',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230219'},
#      'VBA32': {'category': 'malicious',
#       'engine_name': 'VBA32',
#       'engine_version': '5.0.0',
#       'result': 'BScope.TrojanFakeAV.Agent',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'ALYac': {'category': 'malicious',
#       'engine_name': 'ALYac',
#       'engine_version': '1.1.3.1',
#       'result': 'Trojan.EmotetU.Gen.yqW@byYNVrfi',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'TACHYON': {'category': 'undetected',
#       'engine_name': 'TACHYON',
#       'engine_version': '2023-03-20.02',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Cylance': {'category': 'malicious',
#       'engine_name': 'Cylance',
#       'engine_version': '2.0.0.0',
#       'result': 'unsafe',
#       'method': 'blacklist',
#       'engine_update': '20230316'},
#      'Zoner': {'category': 'undetected',
#       'engine_name': 'Zoner',
#       'engine_version': '2.2.2.0',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230319'},
#      'TrendMicro-HouseCall': {'category': 'malicious',
#       'engine_name': 'TrendMicro-HouseCall',
#       'engine_version': '10.0.0.1040',
#       'result': 'TROJ_FAKEAV.SMU4',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Rising': {'category': 'malicious',
#       'engine_name': 'Rising',
#       'engine_version': '25.0.0.27',
#       'result': 'Virus.Kryptik!1.9BB5 (CLASSIC)',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Yandex': {'category': 'undetected',
#       'engine_name': 'Yandex',
#       'engine_version': '5.5.2.24',
#       'result': None,
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'SentinelOne': {'category': 'malicious',
#       'engine_name': 'SentinelOne',
#       'engine_version': '23.1.3.2',
#       'result': 'Static AI - Malicious PE',
#       'method': 'blacklist',
#       'engine_update': '20230216'},
#      'MaxSecure': {'category': 'malicious',
#       'engine_name': 'MaxSecure',
#       'engine_version': '1.0.0.1',
#       'result': 'Trojan.SmartFortress.B',
#       'method': 'blacklist',
#       'engine_update': '20230315'},
#      'Fortinet': {'category': 'malicious',
#       'engine_name': 'Fortinet',
#       'engine_version': '6.4.258.0',
#       'result': 'W32/Ransom.B!tr',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'AVG': {'category': 'malicious',
#       'engine_name': 'AVG',
#       'engine_version': '22.11.7701.0',
#       'result': 'Win32:FakeAlert-CGP [Trj]',
#       'method': 'blacklist',
#       'engine_update': '20230320'},
#      'Panda': {'category': 'malicious',
#       'engine_name': 'Panda',
#       'engine_version': '4.6.4.2',
#       'result': 'Trj/Resdec.c',
#       'method': 'blacklist',
#       'engine_update': '20230319'}},
#     'reputation': 0},
#    'type': 'file',
#    'id': 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7',
#    'links': {'self': 'https://www.virustotal.com/api/v3/files/cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7'}}},
#  'files_behaviours': {'meta': {'count': 2},
#   'data': [{'attributes': {'mitre_attack_techniques': [{'refs': [{'ref': '#signature_matches',
#          'value': 'get system information on Windows'}],
#        'signature_description': 'get system information on Windows',
#        'id': 'T1082',
#        'severity': 'IMPACT_SEVERITY_INFO'},
#       {'refs': [{'ref': '#signature_matches',
#          'value': 'link function at runtime on Windows'}],
#        'signature_description': 'link function at runtime on Windows',
#        'id': 'T1129',
#        'severity': 'IMPACT_SEVERITY_INFO'},
#       {'refs': [{'ref': '#signature_matches',
#          'value': 'accept command line arguments'}],
#        'signature_description': 'accept command line arguments',
#        'id': 'T1059',
#        'severity': 'IMPACT_SEVERITY_INFO'},
#       {'refs': [{'ref': '#signature_matches', 'value': 'parse PE header'}],
#        'signature_description': 'parse PE header',
#        'id': 'T1129',
#        'severity': 'IMPACT_SEVERITY_INFO'},
#       {'refs': [{'ref': '#signature_matches',
#          'value': 'link many functions at runtime'}],
#        'signature_description': 'link many functions at runtime',
#        'id': 'T1129',
#        'severity': 'IMPACT_SEVERITY_INFO'},
#       {'refs': [{'ref': '#signature_matches',
#          'value': 'get geographical location'}],
#        'signature_description': 'get geographical location',
#        'id': 'T1614',
#        'severity': 'IMPACT_SEVERITY_INFO'}],
#      'has_pcap': False,
#      'analysis_date': 1679302048,
#      'sandbox_name': 'CAPA',
#      'has_html_report': False,
#      'behash': '76c6c8e44cd4f1dbddc0f6c2202c1480',
#      'has_evtx': False,
#      'signature_matches': [{'format': 'SIG_FORMAT_CAPA',
#        'rule_src': 'rule:\n  meta:\n    name: calculate modulo 256 via x86 assembly\n    authors:\n      - moritz.raabe@mandiant.com\n    lib: true\n    scope: instruction\n    mbc:\n      - Data::Modulo [C0058]\n    examples:\n      - 9324D1A8AE37A36AE560C37448C9705A:0x4049A9\n  features:\n    #  and ecx, 800000FFh\n    #  and ecx, 0FFh\n    - and:\n      - mnemonic: and\n      - or:\n        - number: 0x800000FF\n        - number: 0xFF\n',
#        'name': 'calculate modulo 256 via x86 assembly',
#        'authors': ['moritz.raabe@mandiant.com']},
#       {'format': 'SIG_FORMAT_CAPA',
#        'rule_src': 'rule:\n  meta:\n    name: create or open file\n    authors:\n      - michael.hunhoff@mandiant.com\n      - joakim@intezer.com\n    lib: true\n    scope: basic block\n    mbc:\n      - File System::Create File [C0016]\n    examples:\n      - B5F85C26D7AA5A1FB4AF5821B6B5AB9B:0x401D7E\n  features:\n    - or:\n      - api: CreateFile\n      - api: CreateFileEx\n      - api: IoCreateFile\n      - api: IoCreateFileEx\n      - api: ZwOpenFile\n      - api: ZwCreateFile\n      - api: NtOpenFile\n      - api: NtCreateFile\n      - api: fopen\n      - api: fopen64\n      - api: fdopen\n      - api: freopen\n      - api: open\n      - api: openat\n',
#        'name': 'create or open file',
#        'authors': ['michael.hunhoff@mandiant.com', 'joakim@intezer.com']},
#       {'format': 'SIG_FORMAT_CAPA',
#        'rule_src': 'rule:\n  meta:\n    name: allocate memory\n    authors:\n      - 0x534a@mailbox.org\n    lib: true\n    scope: basic block\n    mbc:\n      - Memory::Allocate Memory [C0007]\n    examples:\n      - Practical Malware Analysis Lab 03-03.exe_:0x4010EA\n      # ntdll\n      - 563653399B82CD443F120ECEFF836EA3678D4CF11D9B351BB737573C2D856299:0x140001ABA\n  features:\n    - or:\n      - api: kernel32.VirtualAlloc\n      - api: kernel32.VirtualAllocEx\n      - api: kernel32.VirtualAllocExNuma\n      - api: kernel32.VirtualProtect\n      - api: kernel32.VirtualProtectEx\n      - api: NtAllocateVirtualMemory\n      - api: ZwAllocateVirtualMemory\n      - api: NtMapViewOfSection\n      - api: ZwMapViewOfSection\n',
#        'name': 'allocate memory',
#        'authors': ['0x534a@mailbox.org']},
#       {'format': 'SIG_FORMAT_CAPA',
#        'rule_src': 'rule:\n  meta:\n    name: allocate RW memory\n    authors:\n      - 0x534a@mailbox.org\n    lib: true\n    scope: basic block\n    mbc:\n      - Memory::Allocate Memory [C0007]\n    examples:\n      - Practical Malware Analysis Lab 17-02.dll_:0x1000D10D\n  features:\n    - and:\n      - match: allocate memory\n      - number: 0x4 = PAGE_READWRITE\n',
#        'name': 'allocate RW memory',
#        'authors': ['0x534a@mailbox.org']},
#       {'rule_src': 'rule:\n  meta:\n    name: check mutex\n    namespace: host-interaction/mutex\n    authors:\n      - moritz.raabe@mandiant.com\n      - anushka.virgaonkar@mandiant.com\n    scope: basic block\n    mbc:\n      - Process::Check Mutex [C0043]\n    examples:\n      - Practical Malware Analysis Lab 01-01.dll_:0x10001010\n  features:\n    - and:\n      - or:\n        - api: kernel32.OpenMutex\n        - match: create mutex\n        - api: System.Threading.Mutex::OpenExisting\n        - api: System.Threading.Mutex::TryOpenExisting\n      - optional:\n        - or:\n          - api: kernel32.GetLastError\n          - number: 2 = ERROR_FILE_NOT_FOUND\n          - number: 0xB7 = ERROR_ALREADY_EXISTS\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/mutex',
#        'name': 'check mutex',
#        'authors': ['moritz.raabe@mandiant.com',
#         'anushka.virgaonkar@mandiant.com']},
#       {'format': 'SIG_FORMAT_CAPA',
#        'rule_src': 'rule:\n  meta:\n    name: contain loop\n    authors:\n      - moritz.raabe@mandiant.com\n    lib: true\n    scope: function\n    examples:\n      - 08AC667C65D36D6542917655571E61C8:0x406EAA\n  features:\n    - or:\n      - characteristic: loop\n      - characteristic: tight loop\n      - characteristic: recursive call\n',
#        'name': 'contain loop',
#        'authors': ['moritz.raabe@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: get system information on Windows\n    namespace: host-interaction/os/info\n    authors:\n      - moritz.raabe@mandiant.com\n      - joakim@intezer.com\n    scope: function\n    att&ck:\n      - Discovery::System Information Discovery [T1082]\n    examples:\n      - 563653399B82CD443F120ECEFF836EA3678D4CF11D9B351BB737573C2D856299:0x140002280\n  features:\n    - and:\n      - os: windows\n      - or:\n        - api: kernel32.GetSystemInfo\n        - api: kernel32.GetNativeSystemInfo\n        - api: NtQuerySystemInformation\n        - api: NtQuerySystemInformationEx\n        - api: ntdll.RtlGetNativeSystemInformation\n        - api: ZwQuerySystemInformation\n        - api: ZwQuerySystemInformationEx\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/os/info',
#        'name': 'get system information on Windows',
#        'authors': ['moritz.raabe@mandiant.com', 'joakim@intezer.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: write file on Windows\n    namespace: host-interaction/file-system/write\n    authors:\n      - william.ballenthin@mandiant.com\n      - anushka.virgaonkar@mandiant.com\n    scope: function\n    mbc:\n      - File System::Writes File [C0052]\n    examples:\n      - Practical Malware Analysis Lab 01-04.exe_:0x4011FC\n      # ntdll\n      - 563653399B82CD443F120ECEFF836EA3678D4CF11D9B351BB737573C2D856299:0x1400025C4\n  features:\n    - or:\n      - and:\n        - os: windows\n        - optional:\n          - or:\n            - and:\n              - number: 0x40000000 = GENERIC_WRITE\n              - api: kernel32.CreateFile\n            - and:\n              - number: 0x2 = FILE_WRITE_DATA\n              - or:\n                - api: NtCreateFile\n                - api: ZwCreateFile\n        - or:\n          - api: kernel32.WriteFile\n          - api: kernel32.WriteFileEx\n          - api: NtWriteFile\n          - api: ZwWriteFile\n          - api: _fwrite\n          - api: fwrite\n      - api: System.IO.File::WriteAllBytes\n      - api: System.IO.File::WriteAllBytesAsync\n      - api: System.IO.File::WriteAllLines\n      - api: System.IO.File::WriteAllLinesAsync\n      - api: System.IO.File::WriteAllText\n      - api: System.IO.File::WriteAllTextAsync\n      - api: System.IO.File::AppendAllLines\n      - api: System.IO.File::AppendAllLinesAsync\n      - api: System.IO.File::AppendAllText\n      - api: System.IO.File::AppendAllTextAsync\n      - api: System.IO.File::AppendText\n      - api: System.IO.FileInfo::AppendText\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/file-system/write',
#        'name': 'write file on Windows',
#        'authors': ['william.ballenthin@mandiant.com',
#         'anushka.virgaonkar@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: read file on Windows\n    namespace: host-interaction/file-system/read\n    authors:\n      - moritz.raabe@mandiant.com\n      - anushka.virgaonkar@mandiant.com\n    scope: function\n    mbc:\n      - File System::Read File [C0051]\n    examples:\n      - BFB9B5391A13D0AFD787E87AB90F14F5:0x1314567B\n  features:\n    - or:\n      - and:\n        - os: windows\n        - optional:\n          - and:\n            - number: 0x80000000 = GENERIC_READ\n            - api: kernel32.CreateFile\n        - or:\n          - api: kernel32.ReadFile\n          - api: ReadFileEx\n          - api: NtReadFile\n          - api: ZwReadFile\n          - api: _read\n          - api: fread\n      - api: System.IO.File::ReadAllBytes\n      - api: System.IO.File::ReadAllBytesAsync\n      - api: System.IO.File::ReadAllLines\n      - api: System.IO.File::ReadAllLinesAsync\n      - api: System.IO.File::ReadAllText\n      - api: System.IO.File::ReadAllTextAsync\n      - api: System.IO.File::ReadLines\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/file-system/read',
#        'name': 'read file on Windows',
#        'authors': ['moritz.raabe@mandiant.com',
#         'anushka.virgaonkar@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: link function at runtime on Windows\n    namespace: linking/runtime-linking\n    authors:\n      - moritz.raabe@mandiant.com\n    scope: function\n    att&ck:\n      - Execution::Shared Modules [T1129]\n    examples:\n      - 9324D1A8AE37A36AE560C37448C9705A:0x404130\n      - Practical Malware Analysis Lab 01-04.exe_:0x401350\n  features:\n    - and:\n      - os: windows\n      - or:\n        - api: kernel32.LoadLibrary\n        - api: kernel32.GetModuleHandle\n        - api: kernel32.GetModuleHandleEx\n        - api: ntdll.LdrLoadDll\n      - or:\n        - api: kernel32.GetProcAddress\n        - api: ntdll.LdrGetProcedureAddress\n      - optional:\n        - characteristic: indirect call\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'linking/runtime-linking',
#        'name': 'link function at runtime on Windows',
#        'authors': ['moritz.raabe@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: accept command line arguments\n    namespace: host-interaction/cli\n    authors:\n      - moritz.raabe@mandiant.com\n      - anushka.virgaonkar@mandiant.com\n    scope: function\n    att&ck:\n      - Execution::Command and Scripting Interpreter [T1059]\n    examples:\n      - e5369ac309f1be6d77afeeb3edab0ed8:0x402760\n  features:\n    - or:\n      - api: GetCommandLine\n      - api: CommandLineToArgv\n      - api: System.Environment::GetCommandLineArgs\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/cli',
#        'name': 'accept command line arguments',
#        'authors': ['moritz.raabe@mandiant.com',
#         'anushka.virgaonkar@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: parse PE header\n    namespace: load-code/pe\n    authors:\n      - moritz.raabe@mandiant.com\n    scope: function\n    att&ck:\n      - Execution::Shared Modules [T1129]\n    examples:\n      - 9324D1A8AE37A36AE560C37448C9705A:0x403DD0\n  features:\n    # TODO filter out false positives\n    - and:\n      - os: windows\n      - and:\n        - mnemonic: cmp\n        - or:\n          - number: 0x4550 = IMAGE_NT_SIGNATURE (PE)\n          - and:\n            - number: 0x50\n            - number: 0x45\n        - or:\n          - number: 0x5A4D = IMAGE_DOS_SIGNATURE (MZ)\n          - and:\n            - number: 0x4D\n            - number: 0x5A\n        - optional:\n          - and:\n            - offset: 0x3C = IMAGE_DOS_HEADER.e_lfanew\n            - or:\n              - and:\n                - arch: i386\n                - offset: 0x50 = IMAGE_NT_HEADERS.OptionalHeader.SizeOfImage\n                - offset: 0x34 = IMAGE_NT_HEADERS.OptionalHeader.ImageBase\n              - and:\n                - arch: amd64\n                - offset: 0x50 = IMAGE_NT_HEADERS64.OptionalHeader.SizeOfImage\n                - offset: 0x30 = IMAGE_NT_HEADERS64.OptionalHeader.ImageBase\n          - basic block:\n            - and:\n              - offset: 0x3C = IMAGE_DOS_HEADER.e_lfanew\n              - 3 or more:\n                - offset: 0x4 = IMAGE_NT_HEADERS.FileHeader.Machine\n                - offset: 0x6 = IMAGE_NT_HEADERS.FileHeader.NumberOfSections\n                - offset: 0x14 = IMAGE_NT_HEADERS.FileHeader.SizeOfOptionalHeader\n                - offset: 0x16 = IMAGE_NT_HEADERS.FileHeader.Characteristics\n                - offset: 0x28 = IMAGE_NT_HEADERS.OptionalHeader.AddressOfEntryPoint  # for 32 and 64 bit\n                - or:\n                  - and:\n                    - arch: i386\n                    - offset: 0x34 = IMAGE_NT_HEADERS.OptionalHeader.ImageBase\n                    - offset: 0x50 = IMAGE_NT_HEADERS.OptionalHeader.SizeOfImage\n                  - and:\n                    - arch: amd64\n                    - offset: 0x30 = IMAGE_NT_HEADERS.OptionalHeader.ImageBase\n                    - offset: 0x50 = IMAGE_NT_HEADERS64.OptionalHeader.SizeOfImage\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'load-code/pe',
#        'name': 'parse PE header',
#        'authors': ['moritz.raabe@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: terminate process\n    namespace: host-interaction/process/terminate\n    authors:\n      - moritz.raabe@mandiant.com\n      - michael.hunhoff@mandiant.com\n      - anushka.virgaonkar@mandiant.com\n    scope: function\n    mbc:\n      - Process::Terminate Process [C0018]\n    examples:\n      - C91887D861D9BD4A5872249B641BC9F9:0x401A77\n      - 9B7CCAA2AE6A5B96E3110EBCBC4311F6:0x10010307\n  features:\n    - or:\n      - api: System.Diagnostics.Process::Kill\n      - api: System.Diagnostics.Process::WaitForExit\n      - api: System.Diagnostics.Process::WaitForExitAsync\n      - and:\n        - optional:\n          - match: open process\n        - or:\n          - api: kernel32.TerminateProcess\n          - api: ntdll.NtTerminateProcess\n          - api: kernel32.ExitProcess\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/process/terminate',
#        'name': 'terminate process',
#        'authors': ['moritz.raabe@mandiant.com',
#         'michael.hunhoff@mandiant.com',
#         'anushka.virgaonkar@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: get thread local storage value\n    namespace: host-interaction/process\n    authors:\n      - michael.hunhoff@mandiant.com\n    scope: function\n  features:\n    - and:\n      - api: kernel32.TlsGetValue\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/process',
#        'name': 'get thread local storage value',
#        'authors': ['michael.hunhoff@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: set thread local storage value\n    namespace: host-interaction/process\n    authors:\n      - michael.hunhoff@mandiant.com\n    scope: function\n    mbc:\n      - Process::Set Thread Local Storage Value [C0041]\n    examples:\n      - 03B236B23B1EC37C663527C1F53AF3FE:0x18000AE21\n  features:\n    - and:\n      - api: kernel32.TlsSetValue\n      - optional:\n        - match: allocate thread local storage\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/process',
#        'name': 'set thread local storage value',
#        'authors': ['michael.hunhoff@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: allocate thread local storage\n    namespace: host-interaction/process\n    authors:\n      - michael.hunhoff@mandiant.com\n    scope: function\n    mbc:\n      - Process::Allocate Thread Local Storage [C0040]\n    examples:\n      - 03B236B23B1EC37C663527C1F53AF3FE:0x18000ADF6\n  features:\n    - or:\n      - api: kernel32.TlsAlloc\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'host-interaction/process',
#        'name': 'allocate thread local storage',
#        'authors': ['michael.hunhoff@mandiant.com']},
#       {'rule_src': 'rule:\n  meta:\n    name: link many functions at runtime\n    namespace: linking/runtime-linking\n    authors:\n      - moritz.raabe@mandiant.com\n      - joakim@intezer.com\n    scope: function\n    att&ck:\n      - Execution::Shared Modules [T1129]\n    examples:\n      - b7b5e1253710d8927cbe07d52d2d2e10:0x401000\n  features:\n    - or:\n      - and:\n        - os: windows\n        - match: link function at runtime on Windows\n        - or:\n          - count(api(kernel32.GetProcAddress)): 5 or more\n          - count(api(ntdll.LdrGetProcedureAddress)): 5 or more\n      - and:\n        - os: linux\n        - match: link function at runtime on Linux\n        - or:\n          - count(api(dlsym)): 5 or more\n          - count(api(dlvsym)): 5 or more\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'linking/runtime-linking',
#        'name': 'link many functions at runtime',
#        'authors': ['moritz.raabe@mandiant.com', 'joakim@intezer.com']},
#       {'rule_src': '# generated using capa explorer for IDA Pro\nrule:\n  meta:\n    name: get geographical location\n    namespace: collection\n    authors:\n      - moritz.raabe\n    scope: function\n    att&ck:\n      - Discovery::System Location Discovery [T1614]\n    examples:\n      - 9879D201DC5ACA863F357184CD1F170E:0x10001A99\n  features:\n    - or:\n      - api: GetLocaleInfo\n      - api: GetLocaleInfoEx\n      # strings part of requests or parsed from response\n      # "geo" and "zip" are too short\n      # "region" results in FPs mostly related to memory\n      - string: /geolocation/i\n      - string: /geo-location/i\n      - string: /^city/i\n      - string: /region_code/i\n      - string: /region_name/i\n      - string: /^country/i\n      - string: /country_code/i\n      - string: /countrycode/i\n      - string: /country_name/i\n      - string: /continent_code/i\n      - string: /continent_name/i\n      - string: /^latitude/i\n      - string: /^longitude/i\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'collection',
#        'name': 'get geographical location',
#        'authors': ['moritz.raabe']},
#       {'rule_src': 'rule:\n  meta:\n    name: contain a resource (.rsrc) section\n    namespace: executable/pe/section/rsrc\n    authors:\n      - moritz.raabe@mandiant.com\n    scope: file\n    examples:\n      - A933A1A402775CFA94B6BEE0963F4B46:0x41fd25\n  features:\n    - section: .rsrc\n',
#        'format': 'SIG_FORMAT_CAPA',
#        'description': 'executable/pe/section/rsrc',
#        'name': 'contain a resource (.rsrc) section',
#        'authors': ['moritz.raabe@mandiant.com']}],
#      'last_modification_date': 1679302049,
#      'has_memdump': False},
#     'type': 'file_behaviour',
#     'id': 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7_CAPA',
#     'links': {'self': 'https://www.virustotal.com/api/v3/file_behaviours/cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7_CAPA'}},
#    {'attributes': {'processes_created': ['C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E.exe" "C:\\cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7""'],
#      'registry_keys_set': [{'key': 'HKEY_USERS\\S-1-5-21-1275210071-920026266-1060284298-1003\\Software\\Microsoft\\windows\\CurrentVersion\\Internet Settings\\MigrateProxy'},
#       {'key': 'HKEY_USERS\\S-1-5-21-1275210071-920026266-1060284298-1003\\Software\\Microsoft\\windows\\CurrentVersion\\Internet Settings\\ProxyEnable'},
#       {'key': 'HKEY_CURRENT_CONFIG\\Software\\Microsoft\\windows\\CurrentVersion\\Internet Settings\\ProxyEnable'},
#       {'key': 'HKEY_USERS\\S-1-5-21-1275210071-920026266-1060284298-1003\\Software\\Microsoft\\windows\\CurrentVersion\\Internet Settings\\Connections\\SavedLegacySettings'},
#       {'key': 'HKEY_CURRENT_USER\\Software\\Microsoft\\Windows\\CurrentVersion\\Internet Settings\\ZoneMap\\\\ProxyBypass'},
#       {'key': 'HKEY_CURRENT_USER\\Software\\Microsoft\\Windows\\CurrentVersion\\Internet Settings\\ZoneMap\\\\IntranetName'},
#       {'key': 'HKEY_CURRENT_USER\\Software\\Microsoft\\Windows\\CurrentVersion\\Internet Settings\\ZoneMap\\\\UNCAsIntranet'},
#       {'key': 'HKEY_CURRENT_USER\\SOFTWARE\\Microsoft\\Windows\\CurrentVersion\\RunOnce\\529C50FF01A6CA1B670EFB3DD151FC4E'}],
#      'has_pcap': True,
#      'files_written': ['C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E.exe',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E'],
#      'mutexes_opened': ['539D520002A7CB1C680FFC3ED252FD4F',
#       'RasPbFile',
#       '529C50FF01A6CA1B670EFB3DD151FC4E'],
#      'modules_loaded': ['rpcrt4.dll',
#       'psapi.dll',
#       'msimg32.dll',
#       'comdlg32.dll',
#       'kernel32',
#       'user32',
#       'kernel32.dll',
#       'shlwapi.dll',
#       'advapi32.dll',
#       'userenv.dll',
#       'secur32.dll',
#       'shell32.dll',
#       'wsock32',
#       'ws2_32',
#       'comctl32.dll',
#       'rasapi32.dll',
#       'rtutils.dll',
#       'sensapi.dll',
#       'ntdll.dll',
#       'netapi32.dll',
#       'urlmon.dll',
#       'wininet.dll',
#       'c:\\windows\\system32\\mswsock.dll',
#       'hnetcfg.dll',
#       'c:\\windows\\system32\\wshtcpip.dll',
#       'clbcatq.dll',
#       'ole32',
#       'ole32.dll',
#       'c:\\windows\\system32\\rpcrt4.dll',
#       'sxs.dll',
#       'oleaut32.dll',
#       'riched20.dll'],
#      'analysis_date': 1383242437,
#      'sandbox_name': 'VirusTotal Cuckoofork',
#      'has_html_report': True,
#      'files_deleted': ['C:\\cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7',
#       'C:\\cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7'],
#      'has_evtx': False,
#      'services_opened': ['RASMAN'],
#      'last_modification_date': 1558711328,
#      'has_memdump': False,
#      'mutexes_created': ['ShimCacheMutex', 'RasPbFile'],
#      'windows_searched': ['(null) - Shell_TrayWnd'],
#      'files_opened': ['C:\\cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7',
#       'c:\\autoexec.bat',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E.exe',
#       'C:\\WINDOWS\\Registration\\R000000000007.clb',
#       'C:\\WINDOWS\\system32\\shdocvw.dll',
#       'C:\\WINDOWS\\system32\\stdole2.tlb',
#       '\\\\.\\PIPE\\lsarpc',
#       'C:\\cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E.exe',
#       'c:\\autoexec.bat',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E',
#       'C:\\Documents and Settings\\All Users\\Application Data\\529C50FF01A6CA1B670EFB3DD151FC4E\\529C50FF01A6CA1B670EFB3DD151FC4E',
#       'C:\\WINDOWS\\Registration\\R000000000007.clb',
#       'C:\\WINDOWS\\system32\\shdocvw.dll',
#       'C:\\WINDOWS\\system32\\stdole2.tlb']},
#     'type': 'file_behaviour',
#     'id': 'cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7_VirusTotal Cuckoofork',
#     'links': {'self': 'https://www.virustotal.com/api/v3/file_behaviours/cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7_VirusTotal Cuckoofork'}}],
#   'links': {'self': 'https://www.virustotal.com/api/v3/files/cda1646156e1514310a0e7a3f4e1d3889d136000a8bc21e9ae8729c2339d15e7/behaviours?limit=10'}}}
